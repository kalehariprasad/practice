# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.chdir('C:/Users/Admin/Downloads/ICC')

# %%
batting=pd.read_csv('batting_card.csv')
bowling=pd.read_csv('bowling_card.csv')
summary=pd.read_csv('summary.csv')

# %%
batting.head()
# Out:
#    season  match_id match_name home_team away_team                     venue  \
# 0    2022   1298179  ENG v PAK       PAK       ENG  Melbourne Cricket Ground
# 1    2022   1298179  ENG v PAK       PAK       ENG  Melbourne Cricket Ground
# 2    2022   1298179  ENG v PAK       PAK       ENG  Melbourne Cricket Ground
# 3    2022   1298179  ENG v PAK       PAK       ENG  Melbourne Cricket Ground
# 4    2022   1298179  ENG v PAK       PAK       ENG  Melbourne Cricket Ground
#
#         city    country current_innings  innings_id  ... fours sixes  \
# 0  Melbourne  Australia             PAK           1  ...     0     1
# 1  Melbourne  Australia             PAK           1  ...     2     0
# 2  Melbourne  Australia             PAK           1  ...     1     0
# 3  Melbourne  Australia             PAK           1  ...     2     1
# 4  Melbourne  Australia             PAK           1  ...     0     0
#
#    strikeRate  captain isNotOut                 runningScore  runningOver  \
# ...

# %%
pd.set_option('display.max_columns', 50)

# %%
batting.head()
# Out:
#    season  match_id match_name home_team away_team                     venue  \
# 0    2022   1298179  ENG v PAK       PAK       ENG  Melbourne Cricket Ground
# 1    2022   1298179  ENG v PAK       PAK       ENG  Melbourne Cricket Ground
# 2    2022   1298179  ENG v PAK       PAK       ENG  Melbourne Cricket Ground
# 3    2022   1298179  ENG v PAK       PAK       ENG  Melbourne Cricket Ground
# 4    2022   1298179  ENG v PAK       PAK       ENG  Melbourne Cricket Ground
#
#         city    country current_innings  innings_id             name  \
# 0  Melbourne  Australia             PAK           1  Mohammad Rizwan
# 1  Melbourne  Australia             PAK           1       Babar Azam
# 2  Melbourne  Australia             PAK           1   Mohammad Haris
# 3  Melbourne  Australia             PAK           1      Shan Masood
# 4  Melbourne  Australia             PAK           1   Iftikhar Ahmed
#
#           fullName  runs  ballsFaced minutes  fours  sixes strikeRate  \
# ...

# %%
bowling.head()
# Out:
#    season  match_id match_name home_team away_team bowling_team  \
# 0    2022   1298179  ENG v PAK       PAK       ENG          ENG
# 1    2022   1298179  ENG v PAK       PAK       ENG          ENG
# 2    2022   1298179  ENG v PAK       PAK       ENG          ENG
# 3    2022   1298179  ENG v PAK       PAK       ENG          ENG
# 4    2022   1298179  ENG v PAK       PAK       ENG          ENG
#
#                       venue       city    country  innings_id       name  \
# 0  Melbourne Cricket Ground  Melbourne  Australia           1  BA Stokes
# 1  Melbourne Cricket Ground  Melbourne  Australia           1  CR Woakes
# 2  Melbourne Cricket Ground  Melbourne  Australia           1  SM Curran
# 3  Melbourne Cricket Ground  Melbourne  Australia           1  AU Rashid
# 4  Melbourne Cricket Ground  Melbourne  Australia           1  CJ Jordan
#
#        fullName  overs  maidens  conceded  wickets  economyRate  dots  \
# ...

# %%
summary.head()
# Out:
#    season       id                    name   short_name  \
# 0  2022.0  1298179      England v Pakistan    ENG v PAK
# 1  2022.0  1298178         England v India  ENG v INDIA
# 2  2022.0  1298177  New Zealand v Pakistan     NZ v PAK
# 3  2022.0  1298176        India v Zimbabwe  INDIA v ZIM
# 4  2022.0  1298175   Bangladesh v Pakistan    BAN v PAK
#
#                                          description home_team away_team  \
# 0  Final (N), ICC Men's T20 World Cup at Melbourn...       ENG       PAK
# 1  2nd Semi-Final (N), ICC Men's T20 World Cup at...       ENG     INDIA
# 2  1st Semi-Final (N), ICC Men's T20 World Cup at...        NZ       PAK
# 3  42nd Match, Group 2 (N), ICC Men's T20 World C...     INDIA       ZIM
# 4  41st Match, Group 2, ICC Men's T20 World Cup a...       BAN       PAK
#
#       toss_won    decision 1st_inning_score 2nd_inning_score home_score  \
# 0      England  BOWL FIRST            137/8            138/5      138/5
# ...

# %%
batting.shape
# Out:
# (699, 25)

# %%
bowling.shape
# Out:
# (500, 24)

# %%
summary.shape
# Out:
# (45, 45)

# %%
batting.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team', 'venue',
#        'city', 'country', 'current_innings', 'innings_id', 'name', 'fullName',
#        'runs', 'ballsFaced', 'minutes', 'fours', 'sixes', 'strikeRate',
#        'captain', 'isNotOut', 'runningScore', 'runningOver', 'shortText',
#        'commentary', 'link'],
#       dtype='object')

# %%
max(batting['runs'])
# Out:
# 109

# %%
centuries=batting[batting['runs']>100]

# %%
centuries
# Out:
#      season  match_id match_name home_team away_team                  venue  \
# 303    2022   1298161    NZ v SL        NZ        SL  Sydney Cricket Ground
# 356    2022   1298156   BAN v SA        SA       BAN  Sydney Cricket Ground
#
#        city    country current_innings  innings_id         name  \
# 303  Sydney  Australia              NZ           1  GD Phillips
# 356  Sydney  Australia              SA           1   RR Rossouw
#
#            fullName  runs  ballsFaced minutes  fours  sixes strikeRate  \
# 303  Glenn Phillips   104          64      87     10      4     162.50
# 356   Rilee Rossouw   109          56      90      7      8     194.64
#
#      captain  isNotOut                 runningScore  runningOver  \
# 303    False     False  {'wickets': 6, 'runs': 162}         19.4
# 356    False     False  {'wickets': 4, 'runs': 192}         18.3
#
#                           shortText  \
# 303              c Shanaka b Kumara
# 356  c Litton Das b Shakib Al Hasan
#
# ...

# %%
centuries['name']
# Out:
# 303    GD Phillips
# 356     RR Rossouw
# Name: name, dtype: object

# %%
half_centuries=batting[batting['runs']>50]

# %%
half_centuries
# Out:
#      season  match_id   match_name home_team away_team  \
# 13     2022   1298179    ENG v PAK       PAK       ENG
# 21     2022   1298178  ENG v INDIA     INDIA       ENG
# 24     2022   1298178  ENG v INDIA     INDIA       ENG
# 25     2022   1298178  ENG v INDIA     INDIA       ENG
# 30     2022   1298177     NZ v PAK        NZ       PAK
# 32     2022   1298177     NZ v PAK        NZ       PAK
# 33     2022   1298177     NZ v PAK        NZ       PAK
# 37     2022   1298176  INDIA v ZIM     INDIA       ZIM
# 40     2022   1298176  INDIA v ZIM     INDIA       ZIM
# 55     2022   1298175    BAN v PAK       BAN       PAK
# 88     2022   1298173     ENG v SL        SL       ENG
# 110    2022   1298172    AUS v AFG       AUS       AFG
# 126    2022   1298171     IRE v NZ        NZ       IRE
# 147    2022   1298170     PAK v SA       PAK        SA
# 149    2022   1298170     PAK v SA       PAK        SA
# 166    2022   1298169  BAN v INDIA     INDIA       BAN
# ...

# %%
first_innings_half_centureis=half_centuries[half_centuries['innings_id']==1]
chasaing_half_centureis=half_centuries[half_centuries['innings_id']==2]

# %%
first_innings_half_centureis['current_innings'].value_counts()
# Out:
# INDIA    8
# NZ       4
# PAK      4
# SL       3
# SCOT     3
# BAN      2
# AUS      2
# ENG      2
# SA       2
# IRE      1
# WI       1
# ZIM      1
# Name: current_innings, dtype: int64

# %%
indian_plyaer_50s_in_1st_innings=first_innings_half_centureis[first_innings_half_centureis['current_innings']=='INDIA']

# %%
indian_plyaer_50s_in_1st_innings
# Out:
#      season  match_id   match_name home_team away_team  \
# 21     2022   1298178  ENG v INDIA     INDIA       ENG
# 37     2022   1298176  INDIA v ZIM     INDIA       ZIM
# 40     2022   1298176  INDIA v ZIM     INDIA       ZIM
# 166    2022   1298169  BAN v INDIA     INDIA       BAN
# 250    2022   1298164   INDIA v SA     INDIA        SA
# 340    2022   1298157  INDIA v NED     INDIA       NED
# 341    2022   1298157  INDIA v NED     INDIA       NED
# 342    2022   1298157  INDIA v NED     INDIA       NED
#
#                         venue       city    country current_innings  \
# 21              Adelaide Oval   Adelaide  Australia           INDIA
# 37   Melbourne Cricket Ground  Melbourne  Australia           INDIA
# 40   Melbourne Cricket Ground  Melbourne  Australia           INDIA
# 166             Adelaide Oval   Adelaide  Australia           INDIA
# 250             Perth Stadium      Perth  Australia           INDIA
# ...

# %%
chasaing_half_centureis
# Out:
#      season  match_id   match_name home_team away_team  \
# 13     2022   1298179    ENG v PAK       PAK       ENG
# 24     2022   1298178  ENG v INDIA     INDIA       ENG
# 25     2022   1298178  ENG v INDIA     INDIA       ENG
# 32     2022   1298177     NZ v PAK        NZ       PAK
# 33     2022   1298177     NZ v PAK        NZ       PAK
# 173    2022   1298169  BAN v INDIA     INDIA       BAN
# 192    2022   1298168    NED v ZIM       ZIM       NED
# 209    2022   1298167     ENG v NZ       ENG        NZ
# 225    2022   1298166     AFG v SL       AFG        SL
# 238    2022   1298165    AUS v IRE       AUS       IRE
# 261    2022   1298164   INDIA v SA     INDIA        SA
# 262    2022   1298164   INDIA v SA     INDIA        SA
# 293    2022   1298162    BAN v ZIM       BAN       ZIM
# 402    2022   1298153     AUS v SL        SL       AUS
# 424    2022   1298151    BAN v NED       BAN       NED
# 444    2022   1298150  INDIA v PAK       PAK     INDIA
# ...

# %%
chasaing_half_centureis['current_innings'].value_counts()
# Out:
# ENG      3
# NED      3
# IRE      3
# PAK      2
# SL       2
# SA       2
# ZIM      2
# BAN      1
# NZ       1
# AUS      1
# INDIA    1
# NAM      1
# Name: current_innings, dtype: int64

# %%
indian_player_half_century_in_second_innings=chasaing_half_centureis[chasaing_half_centureis['current_innings']=='INDIA']

# %%
indian_player_half_century_in_second_innings
# Out:
#      season  match_id   match_name home_team away_team  \
# 444    2022   1298150  INDIA v PAK       PAK     INDIA
#
#                         venue       city    country current_innings  \
# 444  Melbourne Cricket Ground  Melbourne  Australia           INDIA
#
#      innings_id     name     fullName  runs  ballsFaced minutes  fours  sixes  \
# 444           2  V Kohli  Virat Kohli    82          53      98      6      4
#
#     strikeRate  captain  isNotOut runningScore  runningOver shortText  \
# 444     154.71    False      True           {}          NaN   not out
#
#     commentary  link
# 444        NaN   NaN
